# %%
import sys
sys.path.append('..')
from ray_optim.plot import Plot
import torch
import matplotlib.pyplot as plt

# %%
fig, _ = Plot.plot_data([torch.randn(1,100,2)])

# %%
# %matplotlib inline

fig.show()
plt.show()
# Out:
# /tmp/ipykernel_86013/1681108066.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
